# %% [markdown]
# # Ahmad Masood
# # 20I-1754
# # AI-K
# # Lab 01

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading Files

# %%
df= pd.read_csv("Medicine-Updated.csv")
df
# Out:
#       Intensity                                          Diagnosis       Type  \
# 0    400mg/60mg              Pain, menstrual pain and inflammation     Tablet
# 1    400mg/60mg                                          Hepatitis     Tablet
# 2         150mg                       Pain, Fever and Inflammation     Tablet
# 3         500mg                                              Sugar     Tablet
# 4         400mg                     bronchitis,bacterial sinusitis     Tablet
# ..          ...                                                ...        ...
# 100     200/500  Bacterial Infections and Hospital Acquired Pne...  Injection
# 101     200/500  Bacterial Infections and Hospital Acquired Pne...  Injection
# 102      50/100  Bacterial Infections and Hospital Acquired Pne...  Injection
# 103         100  Bacterial Infections and Hospital Acquired Pne...  Injection
# 104  50/100/250  Bacterial Infections and Hospital Acquired Pne...  Injection
#
# ...

# %%
ECG_df=pd.read_csv("ECG200_TRAIN.csv",delimiter="  ")
ECG_df
# Out:
#     -1.0000000e+00   5.0205548e-01   5.4216265e-01   7.2238348e-01  \
# 0              1.0        0.147647        0.804668        0.367771
# 1             -1.0        0.316646        0.243199        0.370471
# 2             -1.0        1.168874        2.075901        1.760141
# 3              1.0        0.648658        0.752026        2.636231
# 4              1.0        0.404733        1.280859        2.515148
# ..             ...             ...             ...             ...
# 94             1.0        0.581277        0.876188        1.042767
# 95            -1.0        2.689017        2.708703        2.008381
# 96            -1.0        0.197677        0.455417        0.973110
# 97             1.0        0.179500        1.038409        1.946421
# 98             1.0        0.073124        0.776054        2.181336
#
#      1.4288852e+00   2.1365158e+00   2.2811490e+00   1.9362737e+00  \
# 0         0.243894        0.026614       -0.274402        0.096731
# ...

# %% [markdown]
# ## Giving Columns Names

# %%
colName=list(range(1, 98))
colName=[str(i) for i in colName]
ECG_df.set_axis(colName, axis='columns', inplace=True)
ECG_df
# Out:
#       1         2         3         4         5         6         7         8  \
# 0   1.0  0.147647  0.804668  0.367771  0.243894  0.026614 -0.274402  0.096731
# 1  -1.0  0.316646  0.243199  0.370471  1.063738  1.678187  1.759558  1.697717
# 2  -1.0  1.168874  2.075901  1.760141  1.606446  1.949046  1.302842  0.459332
# 3   1.0  0.648658  0.752026  2.636231  3.455716  2.118157  0.520620 -0.188627
# 4   1.0  0.404733  1.280859  2.515148  1.299519  1.453432  0.474275 -1.396562
# ..  ...       ...       ...       ...       ...       ...       ...       ...
# 94  1.0  0.581277  0.876188  1.042767  1.796120  2.541399  2.246653  1.500387
# 95 -1.0  2.689017  2.708703  2.008381  2.235800  1.516982  0.029916 -0.561346
# 96 -1.0  0.197677  0.455417  0.973110  1.935956  2.259463  1.741341  1.158296
# 97  1.0  0.179500  1.038409  1.946421  2.705141  1.670706 -0.101167 -1.578876
# 98  1.0  0.073124  0.776054  2.181336  3.440325  2.168475  0.497315 -0.924284
#
# ...

# %% [markdown]
# ## Getting Unique Values and their Indexes

# %%
uninque_values=ECG_df["1"].unique()

# %%
ECG_df["1"].value_counts()
# Out:
#  1.0    69
# -1.0    30
# Name: 1, dtype: int64

# %%
index_1=[]
index_0=[]
for i in range(len(ECG_df["1"])):
    if ECG_df["1"][i]==1.0:
        index_1.append(i)
    else:
        index_0.append(i)

# %%
count_unique=ECG_df["1"].value_counts()

# %%
len(count_unique)
# Out:
# 2

# %%
l1=[]
l2=[]
l3=[]
l4=[]

for i in range(len(index_1)):
    if i<17:
        l1.append(index_1[i])
    elif i>16 and i<34:
        l2.append(index_1[i])
    elif i>33 and i<51:
        l3.append(index_1[i])
    elif i>50 and i<69:
        l4.append(index_1[i])

# %%
for i in range(len(index_0)):
    if i<7:
        l1.append(index_0[i])
    elif i>6 and i<14:
        l2.append(index_0[i])
    elif i>13 and i<22:
        l3.append(index_0[i])
    elif i>21 and i<30:
        l4.append(index_0[i])

# %%
len(l4)
# Out:
# 26

# %% [markdown]
# ## Shuffling

# %%
train_index_1= l1+l2+l3
test_index_1=l4

train_index_2= l1+l2+l4
test_index_2=l3

train_index_3= l1+l4+l3
test_index_3=l2

train_index_4= l4+l2+l3
test_index_4=l1

# %% [markdown]
# ## Getting Values for training and testing

# %%
train_data_1=[]
test_data_1=[]

train_data_2=[]
test_data_2=[]

train_data_3=[]
test_data_3=[]

train_data_4=[]
test_data_4=[]

# %%
for i in range(len(train_index)):
    train_data_1.append(ECG_df.iloc[train_index[i]].to_list())

for i in range(len(train_index)):
    train_data_2.append(ECG_df.iloc[train_index[i]].to_list())

for i in range(len(train_index)):
    train_data_3.append(ECG_df.iloc[train_index[i]].to_list())
    
for i in range(len(train_index)):
    train_data_4.append(ECG_df.iloc[train_index[i]].to_list())

# %%
for i in range(len(test_index)):
    test_data_1.append(ECG_df.iloc[test_index[i]].to_list())
    
for i in range(len(test_index)):
    test_data_2.append(ECG_df.iloc[test_index[i]].to_list())
    
for i in range(len(test_index)):
    test_data_3.append(ECG_df.iloc[test_index[i]].to_list())
    
for i in range(len(test_index)):
    test_data_4.append(ECG_df.iloc[test_index[i]].to_list())

# %%
len(test_data_4)
# Out:
# 25

# %% [markdown]
# ## Making Data Frames and Splitting

# %%
train_df_1=pd.DataFrame(train_data_1)
train_df_2=pd.DataFrame(train_data_2)
train_df_3=pd.DataFrame(train_data_3)
train_df_4=pd.DataFrame(train_data_4)

# %%
x_train_1=train_df_1.iloc[: , 1:]
x_train_2=train_df_2.iloc[: , 1:]
x_train_3=train_df_3.iloc[: , 1:]
x_train_4=train_df_4.iloc[: , 1:]

y_train_1=train_df_1.iloc[: , :1]
y_train_2=train_df_2.iloc[: , :1]
y_train_3=train_df_3.iloc[: , :1]
y_train_4=train_df_4.iloc[: , :1]

# %%
test_df_1=pd.DataFrame(test_data_1)
test_df_2=pd.DataFrame(test_data_2)
test_df_3=pd.DataFrame(test_data_3)
test_df_4=pd.DataFrame(test_data_4)

# %%
x_test_1=test_df_1.iloc[: , 1:]
x_test_2=test_df_2.iloc[: , 1:]
x_test_3=test_df_3.iloc[: , 1:]
x_test_4=test_df_4.iloc[: , 1:]


y_test_1=test_df_1.iloc[: , :1]
y_test_2=test_df_2.iloc[: , :1]
y_test_3=test_df_3.iloc[: , :1]
y_test_4=test_df_4.iloc[: , :1]

# %% [markdown]
# ## Importing Libraries

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Applying Models

# %%
knn = KNeighborsClassifier()
knn.fit(x_train_1, y_train_1)
test_data_predicted_1= knn.predict(x_test_1)
print(accuracy_score(test_data_predicted_1, y_test_1))
# Out:
# 0.88

# %%
knn = KNeighborsClassifier()
knn.fit(x_train_2, y_train_2)
test_data_predicted_2= knn.predict(x_test_2)
print(accuracy_score(test_data_predicted_2, y_test_2))
# Out:
# 0.88

# %%
knn = KNeighborsClassifier()
knn.fit(x_train_3, y_train_3)
test_data_predicted_3= knn.predict(x_test_3)
print(accuracy_score(test_data_predicted_3, y_test_3))
# Out:
# 0.88

# %%
knn = KNeighborsClassifier()
knn.fit(x_train_4, y_train_4)
test_data_predicted_4= knn.predict(x_test_4)
print(accuracy_score(test_data_predicted_4, y_test_4))
# Out:
# 0.88

# %% [markdown]
# ## K-Fold

# %%
cross_val_feat=ECG_df.iloc[: , 1:]
cross_val_labels=ECG_df.iloc[: , :1]

# %%
model=KNeighborsClassifier()
scores = cross_val_score(model, cross_val_feat, cross_val_labels, cv=4)
scores
# Out:
# array([0.76      , 0.88      , 0.88      , 0.83333333])

# %%
np.mean(scores)
# Out:
# 0.8383333333333334

# %% [markdown]
# ## Train Test Split

# %%
X=cross_val_feat
y=cross_val_labels

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
test_data_predicted= knn.predict(X_test)
print(accuracy_score(test_data_predicted, y_test))
# Out:
# 0.8181818181818182

# %% [markdown]
# ## Manual Splitting

# %%
ECG_df
# Out:
#       1         2         3         4         5         6         7         8  \
# 0   1.0  0.147647  0.804668  0.367771  0.243894  0.026614 -0.274402  0.096731
# 1  -1.0  0.316646  0.243199  0.370471  1.063738  1.678187  1.759558  1.697717
# 2  -1.0  1.168874  2.075901  1.760141  1.606446  1.949046  1.302842  0.459332
# 3   1.0  0.648658  0.752026  2.636231  3.455716  2.118157  0.520620 -0.188627
# 4   1.0  0.404733  1.280859  2.515148  1.299519  1.453432  0.474275 -1.396562
# ..  ...       ...       ...       ...       ...       ...       ...       ...
# 94  1.0  0.581277  0.876188  1.042767  1.796120  2.541399  2.246653  1.500387
# 95 -1.0  2.689017  2.708703  2.008381  2.235800  1.516982  0.029916 -0.561346
# 96 -1.0  0.197677  0.455417  0.973110  1.935956  2.259463  1.741341  1.158296
# 97  1.0  0.179500  1.038409  1.946421  2.705141  1.670706 -0.101167 -1.578876
# 98  1.0  0.073124  0.776054  2.181336  3.440325  2.168475  0.497315 -0.924284
#
# ...

# %%
train_df=ECG_df.iloc[:69]
test_df=ECG_df.iloc[69:]

# %%
x_train_m=train_df.iloc[:,1:]
y_train_m=train_df.iloc[:,:1]

x_test_m=test_df.iloc[:,1:]
y_test_m=test_df.iloc[:,:1]

# %%
knn.fit(x_train_m, y_train_m)
test_data_predicted_m= knn.predict(x_test_m)
print(accuracy_score(test_data_predicted_m, y_test_m))
# Out:
# 0.8333333333333334

# %% [markdown]
# # Report

# %% [markdown]
# ### Manual K fold gives 0.88 Accuracy while built in gives 0.838
# ### Manual Splitting gives 0.83 Accuracy while built in gives 0.818
